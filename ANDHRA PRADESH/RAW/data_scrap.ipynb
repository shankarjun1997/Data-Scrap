# %%
import os
import pandas as pd

# Define input and output paths
input_path = "C:/Users/ADMIN/Desktop/Python programming tutorial/Data-Scrap/ANDHRA PRADESH/RAW"
output_path = "C:/Users/ADMIN/Desktop/Python programming tutorial/Data-Scrap/ANDHRA PRADESH/TRANSFORMED"

# Ensure output directory exists
os.makedirs(output_path, exist_ok=True)

# List CSV files efficiently
files = [os.path.join(input_path, f) for f in os.listdir(input_path) if f.endswith(".csv")]
print(f"Found {len(files)} CSV files: {files}")

# Define transformation function
def transform_csv(df, new_column_order):
    """Transform a DataFrame by selecting and reordering specified columns."""
    # Keep only columns that exist in the DataFrame from the desired order
    existing_columns = [col for col in new_column_order if col in df.columns]
    df = df[existing_columns]
    return df
# Name,Address,Street,Municipality,Categories,Phone,Phones,Claimed,Review Count,Average Rating

# Desired columns
new_columns = ['Name', 'Address', 'Category', 'Phone', 'Avg_review', 'Reviews', 'Website', 'Maps_url']

# Process each CSV file individually
for file in files:
    try:
        # Read the CSV
        df = pd.read_csv(file)
        print(f"Processing: {os.path.basename(file)} - Shape: {df.shape}")

        # Apply transformations (select and reorder columns) 
        df_transformed = transform_csv(df, new_columns)

        # Handle missing values and reset index
        df_cleaned = df_transformed.dropna(how='all').reset_index(drop=False)
        print(f"Cleaned shape: {df_cleaned.shape}")

        # Define output file path
        output_file = os.path.join(output_path, f"{os.path.basename(file)}_transformed.csv")

        # Save to CSV
        df_cleaned.to_csv(output_file, index=False)
        print(f"Saved: {output_file}")

    except Exception as e:
        print(f"Error processing {os.path.basename(file)}: {e}")

print("All files processed successfully!")
# Out:
# Found 8 CSV files: ['C:/Users/ADMIN/Desktop/Python programming tutorial/Data-Scrap/ANDHRA PRADESH/RAW\\AP-Pooja_store.csv', 'C:/Users/ADMIN/Desktop/Python programming tutorial/Data-Scrap/ANDHRA PRADESH/RAW\\hospital.csv', 'C:/Users/ADMIN/Desktop/Python programming tutorial/Data-Scrap/ANDHRA PRADESH/RAW\\ladies_emporium.csv', 'C:/Users/ADMIN/Desktop/Python programming tutorial/Data-Scrap/ANDHRA PRADESH/RAW\\lodge.csv', 'C:/Users/ADMIN/Desktop/Python programming tutorial/Data-Scrap/ANDHRA PRADESH/RAW\\mall.csv', 'C:/Users/ADMIN/Desktop/Python programming tutorial/Data-Scrap/ANDHRA PRADESH/RAW\\salons.csv', 'C:/Users/ADMIN/Desktop/Python programming tutorial/Data-Scrap/ANDHRA PRADESH/RAW\\school.csv', 'C:/Users/ADMIN/Desktop/Python programming tutorial/Data-Scrap/ANDHRA PRADESH/RAW\\textile&handloom.csv']
# Processing: AP-Pooja_store.csv - Shape: (123, 7)
# Cleaned shape: (120, 7)
# ...

# %%
import requests as re
from bs4 import BeautifulSoup

# %%
url = "https://www.google.com/localservices/prolist?g2lbs=AAEPWCuO9tPYiVBLFJ4MgdbMz6nkIqcJ5wEsmiZCGbBOmw8c0VZ6EMoo9b6PfQo8TNv2Ec-tiKsJJINHKb8pMtx2pRiEyrRBfA%3D%3D&hl=en_GB&gl=in&cs=1&ssta=1&q=salon%20in%20andhra%20pradesh&oq=salon%20in%20andhra%20pradesh&slp=...&src=2&serdesk=1&sa=X&ved=2ahUKEwiQqd-dnpOMAxU07TgGHWeZH2MQjGp6BAg0EAE&scp=ChFnY2lkOmJlYXV0eV9zYWxvbhJQEhIJf9STrvhGNToRg82tlb670TMaEgmRt5Jr8F9jMBGmE0KFoU-M1yIOQW5kaHJhIFByYWRlc2gqFA1uRYYHFbu7wC0diaNsCyWtkoUyMAAaBXNhbG9uIhdzYWxvbiBpbiBhbmRocmEgcHJhZGVzaCoMQmVhdXR5IFNhbG9u"

response = re.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.content,'html.parser')
    print(soup)

for location in loc:
        name = location.find('h2').text      # Example: Name of the location in <h2>
        coordinates = location.find('span').text  # Example: Coordinates in <span>
        print(f'Location: {name}, Coordinates: {coordinates}')
else:
    print(f'Failed to retrieve data. Status code: {response.status_code}')
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-GB"><head><base href="https://www.google.com/"/><link href="//www.gstatic.com" rel="preconnect"/><meta content="origin" name="referrer"/><script nonce="TwdYmKgm8QKcBMC5Ze1JMg">window['ppConfig'] = {productName: 'AdsHomeservicesConsumerUi', deleteIsEnforced:  true , sealIsEnforced:  true , heartbeatRate:  0.5 , periodicReportingRateMillis:  60000.0 , disableAllReporting:  false };(function(){'use strict';function k(a){var b=0;return function(){return b<a.length?{done:!1,value:a[b++]}:{done:!0}}}var l=typeof Object.defineProperties=="function"?Object.defineProperty:function(a,b,c){if(a==Array.prototype||a==Object.prototype)return a;a[b]=c.value;return a};
# ...

# %%
loc = soup.find_all('div',class_='RwxOKe')
loc
# Out:
# [<div class="RwxOKe"></div>,
#  <div class="RwxOKe"></div>,
#  <div class="RwxOKe"></div>,
#  <div class="RwxOKe"></div>,
#  <div class="RwxOKe"></div>,
#  <div class="RwxOKe"></div>,
#  <div class="RwxOKe"></div>,
#  <div class="RwxOKe"></div>,
#  <div class="RwxOKe"></div>,
#  <div class="RwxOKe"></div>,
#  <div class="RwxOKe"></div>,
#  <div class="RwxOKe"></div>,
#  <div class="RwxOKe"></div>,
#  <div class="RwxOKe"></div>,
#  <div class="RwxOKe"></div>,
#  <div class="RwxOKe"></div>,
#  <div class="RwxOKe"></div>,
#  <div class="RwxOKe"></div>,
#  <div class="RwxOKe"></div>]

# %%
for location in loc:
        name = location.find('h2').text      # Example: Name of the location in <h2>
        coordinates = location.find('span').text  # Example: Coordinates in <span>
        print(f'Location: {name}, Coordinates: {coordinates}')
else:
    print(f'Failed to retrieve data. Status code: {response.status_code}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 2
#       1 for location in loc:
# ----> 2         name = location.find('h2').text      # Example: Name of the location in <h2>
#       3         coordinates = location.find('span').text  # Example: Coordinates in <span>
#       4         print(f'Location: {name}, Coordinates: {coordinates}')
#
# AttributeError: 'NoneType' object has no attribute 'text'
